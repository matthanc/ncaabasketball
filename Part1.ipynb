# %% [markdown]
# <a href="https://colab.research.google.com/github/matthanc/ncaabasketball/blob/main/Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# Start a new Google Colab Notebook and validate the libraries:
# 1. Validate that Python is at least 3.6.
# 2. Validate that NumPy is at least 1.18.
# 3. Validate that pandas is at least 1.0.
# 4. Validate that TensorFlow is at least 2.2.

# %%
print("The Python version is",sys.version)
print("The Numpy version is",np.__version__)
print("The Pandas version is",pd.__version__)
print("The TensorFlow version is",tf.__version__)
# Out:
# The Python version is 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]
# The Numpy version is 1.19.4
# The Pandas version is 1.1.4
# The TensorFlow version is 2.3.1

# %% [markdown]
# 1. Create a 4 column DataFrame with 10 rows, the first column being a date field and the rest numbers.
# 2. Fill the first column with the first day of each month for 3 years (for example: 1/1/2018, 2/1/2018).
# 3. Fill the next 2 columns with random numbers.
# 4. Fill the 4th column with the difference of the first 2 data columns (for example: Col3 - Col2).
# 5. Break the DataFrame into 3 different DataFrames based on the dates (for example: 2018, 2019, 2020)

# %%
df = pd.DataFrame()
df['date'] = pd.date_range('2021-01-01', periods = 36, freq = 'MS')
df['num1'] = np.random.randint(1,99,df.shape[0])
df['num2'] = np.random.randint(1,99,df.shape[0])
df['diff'] = df['num2'] - df['num1']
df2021 = df.loc[(df['date'] > '2020-12-31') & (df['date'] <= '2021-12-31')]
df2022 = df.loc[(df['date'] > '2021-12-31') & (df['date'] <= '2022-12-31')]
df2023 = df.loc[(df['date'] > '2022-12-31') & (df['date'] <= '2023-12-31')]

print(df2021)
print(df2022)
print(df2023)
# Out:
#          date  num1  num2  diff
# 0  2021-01-01    59    75    16
# 1  2021-02-01    73    82     9
# 2  2021-03-01    39     4   -35
# 3  2021-04-01    63    27   -36
# 4  2021-05-01     2    98    96
# 5  2021-06-01    30    71    41
# 6  2021-07-01    53    88    35
# 7  2021-08-01    15    85    70
# 8  2021-09-01    94    73   -21
# 9  2021-10-01    76    47   -29
# 10 2021-11-01    16    19     3
# 11 2021-12-01    18    37    19
#          date  num1  num2  diff
# 12 2022-01-01    34    27    -7
# 13 2022-02-01    50    96    46
# 14 2022-03-01    64    11   -53
# 15 2022-04-01    65    94    29
# 16 2022-05-01    88    97     9
# 17 2022-06-01    27    53    26
# 18 2022-07-01    20    47    27
# 19 2022-08-01    37    19   -18
# 20 2022-09-01    18    13    -5
# 21 2022-10-01    13    65    52
# 22 2022-11-01    58    89    31
# 23 2022-12-01    40     8   -32
#          date  num1  num2  diff
# 24 2023-01-01    45    51     6
# 25 2023-02-01    26    12   -14
# ...

# %% [markdown]
# Create a neural network that can convert Celsius to Fahrenheit and examine the weights.
# 1. Using TensorFlow and Keras build a single layered network with a single input and a single output and a single neuron.
# 2. Using NumPy generate ~20 input/output values to test
# 3. Train the neural network on your data.
# 4. Test the neural network to see if it is working.
# 5. Examine the weights to see if they match F = C * 1.8 + 32F=C∗1.8+32.

# %%
tempdf = pd.DataFrame()
tempdf['Celsius'] = np.random.randint(0,60,20)
tempdf['Farenheit'] = tempdf['Celsius'] * 1.8 + 32
xtrain = tempdf['Celsius']
ytrain = tempdf['Farenheit']
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units = 1, input_shape = [1]))
model.compile(optimizer = tf.keras.optimizers.Adam(1), loss = 'mean_squared_error')
epochs_hist = model.fit(xtrain, ytrain, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1224.4006
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 246.9643
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 809.3475
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 750.6011
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 361.5632
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 217.8188
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 379.2790
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 517.4799
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 443.8966
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 273.5587
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 187.0419
# Epoch 12/500
# ...

# %%
temp_C = 48
temp_F = model.predict([temp_C])
print(temp_C, 'celsius converted to fahrenheit is', temp_F)
# Out:
# 48 celsius converted to fahrenheit is [[118.40001]]

# %%
model.get_weights()
# Out:
# [array([[1.8000003]], dtype=float32), array([31.999992], dtype=float32)]
